# %% [markdown]
# # Nightlight Summary Statistics Model

# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.insert(0, '../utils')
import model_utils
import data_utils

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install google-cloud-storage
# !source ../.env

# %%
import dotenv
dotenv.load_dotenv("../.env", override=True)
from google.cloud import storage
storage_client = storage.Client()

# %% [markdown]
# ## File Locations

# %%
# Google Cloud Storage
bucket_name = 'tm-geospatial'
directory = 'poverty-prediction-datasets'

# Destination paths
ntl_summary_stats_file = '../data/nightlights_summary_stats.csv'
dhs_indicators_file = '../data/dhs_indicators.csv'

# %% [markdown]
# ## Download Datasets

# %%
# Download from Google Cloud Storage
data_utils.download_from_bucket('nightlights_summary_stats.csv', directory, ntl_summary_stats_file, bucket_name);
data_utils.download_from_bucket('dhs_indicators.csv', directory, dhs_indicators_file, bucket_name);
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-10-41e3b6792274> in <module>
#       1 # Download from Google Cloud Storage
# ----> 2 data_utils.download_from_bucket('nightlights_summary_stats.csv', directory, ntl_summary_stats_file, bucket_name);
#       3 data_utils.download_from_bucket('dhs_indicators.csv', directory, dhs_indicators_file, bucket_name);
#
# ~/code/aicasts/aicasts.com/23-ph-poverty-mapping/ph-poverty-mapping/utils/data_utils.py in download_from_bucket(blob_name, directory, destination_file_name, bucket_name)
#     658     """
#     659     storage_client = storage.Client()
# --> 660     bucket = storage_client.get_bucket(bucket_name)
#     661     blob = bucket.blob("{}/{}".format(directory, blob_name))
#     662
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/google/cloud/storage/client.py in get_bucket(self, bucket_or_name, timeout, if_metageneration_match, if_metageneration_not_match)
#     359             timeout=timeout,
#     360             if_metageneration_match=if_metageneration_match,
# --> 361             if_metageneration_not_match=if_metageneration_not_match,
#     362         )
#     363         return bucket
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/google/cloud/storage/bucket.py in reload(self, client, projection, timeout, if_metageneration_match, if_metageneration_not_match)
#     934             timeout=timeout,
#     935             if_metageneration_match=if_metageneration_match,
# --> 936             if_metageneration_not_match=if_metageneration_not_match,
#     937         )
#     938
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/google/cloud/storage/_helpers.py in reload(self, client, projection, timeout, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match)
#     208             _target_object=self,
#     209             timeout=timeout,
# --> 210             retry=DEFAULT_RETRY,
#     211         )
#     212         self._set_properties(api_response)
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/google/cloud/storage/_http.py in api_request(self, *args, **kwargs)
#      61             if retry:
#      62                 call = retry(call)
# ---> 63         return call()
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     284                 sleep_generator,
#     285                 self._deadline,
# --> 286                 on_error=on_error,
#     287             )
#     288
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     182     for sleep in sleep_generator:
#     183         try:
# --> 184             return target()
#     185
#     186         # pylint: disable=broad-except
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     436
#     437         if not 200 <= response.status_code < 300:
# --> 438             raise exceptions.from_http_response(response)
#     439
#     440         if expect_json and response.content:
#
# Forbidden: 403 GET https://storage.googleapis.com/storage/v1/b/tm-geospatial?projection=noAcl&prettyPrint=false: storage@geo-ai-project.iam.gserviceaccount.com does not have storage.buckets.get access to the Google Cloud Storage bucket.

# %%
# !wget https://raw.githubusercontent.com/thinkingmachines/ph-poverty-mapping/master/data/nightlights_summary_stats.csv

# %% [markdown]
# ## Load Datasets

# %%
# Load nighttime lights dataset
ntl_summary_stats = pd.read_csv(ntl_summary_stats_file, encoding="ISO-8859-1")
dhs_indicators = pd.read_csv(dhs_indicators_file)
dhs = ntl_summary_stats.merge(dhs_indicators, left_on='DHSCLUST', right_on='Cluster number')

# Define feature columns
feature_cols = ['cov', 'kurtosis', 'max', 'mean', 'median', 'min', 'skewness', 'std']

# %% [markdown]
# ## Correlations

# %%
data_utils.plot_corr(
    data=dhs,
    features_cols=feature_cols,
    indicator = 'Wealth Index',
    figsize=(5,3)
)

# %% [markdown]
# ## Machine Learning Pipeline

# %% [markdown]
# ### Configuration

# %%
# Scoring metrics
scoring = {
    'r2': data_utils.pearsonr2,
    'rmse': data_utils.rmse
}

# Indicators of interest
indicators = [
    'Wealth Index',
    'Education completed (years)',
    'Access to electricity',
    'Access to water (minutes)'
]

# %%
import wandb
wandb.init(project="tm-poverty-prediction")
# Out:
# Finishing last run (ID:276pjdjy) before initializing another...
# <br/>Waiting for W&B process to finish, PID 26273<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/Users/shoaib/code/aicasts/aicasts.com/23-ph-poverty-mapping/ph-poverty-mapping/notebooks/wandb/run-20201216_225408-276pjdjy/logs/debug.log</code>
# Find internal logs for this run at: <code>/Users/shoaib/code/aicasts/aicasts.com/23-ph-poverty-mapping/ph-poverty-mapping/notebooks/wandb/run-20201216_225408-276pjdjy/logs/debug-internal.log</code>
# Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">soft-wood-4</strong>: <a href="https://wandb.ai/sabman/tm-poverty-prediction/runs/276pjdjy" target="_blank">https://wandb.ai/sabman/tm-poverty-prediction/runs/276pjdjy</a><br/>
# ...Successfully finished last run (ID:276pjdjy). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.12<br/>
#                 Syncing run <strong style="color:#cdcd00">dazzling-dawn-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/sabman/tm-poverty-prediction" target="_blank">https://wandb.ai/sabman/tm-poverty-prediction</a><br/>
#                 Run page: <a href="https://wandb.ai/sabman/tm-poverty-prediction/runs/7kg2xafd" target="_blank">https://wandb.ai/sabman/tm-poverty-prediction/runs/7kg2xafd</a><br/>
#                 Run data is saved locally in <code>/Users/shoaib/code/aicasts/aicasts.com/23-ph-poverty-mapping/ph-poverty-mapping/notebooks/wandb/run-20201216_225511-7kg2xafd</code><br/><br/>
# <h1>Run(7kg2xafd)</h1><p></p><iframe src="https://wandb.ai/sabman/tm-poverty-prediction/runs/7kg2xafd" style="border:none;width:100%;height:400px"></iframe>

# %% [markdown]
# ### Random Forest

# %%
predictions = model_utils.evaluate_model(
    data=dhs,
    feature_cols=feature_cols, 
    indicator_cols=indicators, 
    scoring=scoring,
    model_type='random_forest', 
    refit='r2', 
    search_type='random', 
    n_splits=5, 
    n_iter=10,
    wandb=wandb
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d9b78b473697> in <module>
#       9     n_splits=5,
#      10     n_iter=10,
# ---> 11     wandb=wandb
#      12 )
#
# ~/code/aicasts/aicasts.com/23-ph-poverty-mapping/ph-poverty-mapping/utils/model_utils.py in evaluate_model(data, feature_cols, indicator_cols, wandb, model_type, scoring, refit, search_type, n_splits, n_iter, task_type, plot_importance, figsize, std_scale, minmax_scale, polynomial, poly_degree, n_workers, verbose, plot)
#     167             poly_degree=poly_degree,
#     168             n_workers=n_workers,
# --> 169             verbose=verbose,
#     170         )
#     171
#
# ~/code/aicasts/aicasts.com/23-ph-poverty-mapping/ph-poverty-mapping/utils/model_utils.py in nested_cross_validation(model, X, y, param_grid, scoring, refit, search_type, n_splits, n_iter, std_scale, minmax_scale, polynomial, poly_degree, task_type, n_workers, verbose)
#     443         scoring=scoring,
#     444         verbose=verbose,
# --> 445         return_train_score=True,
#     446     )
#     447
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     246             return_times=True, return_estimator=return_estimator,
#     247             error_score=error_score)
# --> 248         for train, test in cv.split(X, y, groups))
#     249
#     250     zipped_scores = list(zip(*scores))
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### XGBoost

# %%
predictions = model_utils.evaluate_model(
    data=dhs,
    feature_cols=feature_cols, 
    indicator_cols=indicators, 
    scoring=scoring,
    model_type='xgboost', 
    refit='r2', 
    search_type='random', 
    n_splits=5, 
    n_iter=10,
    wandb=wandb
)
# Out:
# Socioeconomic indicator: Wealth Index
# fit_time : 390.4566
# [470.15122581 474.70001698 460.70117021 461.23308086  85.49752998]
# score_time : 0.0534
# [0.02178717 0.01527619 0.21031284 0.01220727 0.00749803]
# test_r2 : 0.5233
# [0.49031741 0.5692901  0.53040045 0.54183364 0.48449863]
# train_r2 : 0.9417
# [0.92266834 0.95745436 0.9492415  0.93094744 0.94821355]
# test_rmse : 49378.8370
# [52125.32797756 48324.16463454 46333.65040267 49666.98160261
#  50444.06022253]
# train_rmse : 17495.1678
# [20319.77071061 14520.23950273 16771.52172365 19112.14134611
#  16752.16560533]
# [23:14:52] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# Best estimator: Pipeline(steps=[('regressor',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=0.9553410014550571,
#                               gamma=2.891095842056666, gpu_id=-1,
#                               importance_type='gain',
#                               interaction_constraints='',
#                               learning_rate=0.013648111706918705,
#                               max_delta_step=0, max_depth=6, min_child_weight=3,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=1155, n_jobs=-1, num_parallel_tree=1,
#                               objective='reg:linear', random_state=42,
#                               reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                               subsample=0.9677564361842282, tree_method='exact',
#                               validate_parameters=1, verbosity=None))])
# Socioeconomic indicator: Education completed (years)
# fit_time : 318.8431
# [385.48524499 383.01173878 384.61313891 385.25053096  55.85500622]
# score_time : 0.0101
# [0.01475215 0.00668526 0.01297212 0.01126099 0.00496912]
# test_r2 : 0.3350
# [0.31390859 0.29734647 0.36466383 0.35991311 0.33903206]
# train_r2 : 0.8237
# [0.80900876 0.82840932 0.82924412 0.81982043 0.83207623]
# test_rmse : 2.0494
# [2.05868564 2.3165177  1.91341063 1.99245642 1.96599874]
# train_rmse : 1.1021
# [1.14745488 1.0546507  1.10197619 1.12072664 1.08571885]
# [23:29:34] WARNING: /Users/travis/build/dmlc/xgboost/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# Best estimator: Pipeline(steps=[('regressor',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=0.9553410014550571,
#                               gamma=2.891095842056666, gpu_id=-1,
#                               importance_type='gain',
#                               interaction_constraints='',
#                               learning_rate=0.013648111706918705,
#                               max_delta_step=0, max_depth=6, min_child_weight=3,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=1155, n_jobs=-1, num_parallel_tree=1,
#                               objective='reg:linear', random_state=42,
#                               reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                               subsample=0.9677564361842282, tree_method='exact',
#                               validate_parameters=1, verbosity=None))])

# %% [markdown]
# ### Lasso Regression

# %%
predictions = model_utils.evaluate_model(
    data=dhs,
    feature_cols=feature_cols, 
    indicator_cols=indicators, 
    scoring=scoring,
    model_type='lasso', 
    refit='r2', 
    search_type='grid', 
    n_splits=5
)
# Out:
# Socioeconomic indicator: Wealth Index
# fit_time : 0.9091
# [0.93470526 1.08434105 1.08536816 1.00931931 0.43180513]
# train_rmse : 58931.7357
# [58605.30126604 58879.74020149 59563.02554407 58505.17421725
#  59105.43716706]
# train_r2 : 0.3097
# [0.31065152 0.2983289  0.31643954 0.31158217 0.31134271]
# test_rmse : 59522.6414
# [61341.91442325 59672.03977646 57002.79533742 61033.15065271
#  58563.30665249]
# score_time : 0.0020
# [0.00177836 0.00235581 0.00225067 0.00192952 0.00171423]
# test_r2 : 0.2988
# [0.28366014 0.34585649 0.26527583 0.29617549 0.30286331]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Lasso(alpha=1.49816047538945, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=42,
#    selection='cyclic', tol=0.0001, warm_start=False))])
# Socioeconomic indicator: Education completed (years)
# fit_time : 0.3194
# [0.3164506  0.33293986 0.30984259 0.31052399 0.32726908]
# train_rmse : 2.0533
# [2.06495704 2.02005073 2.05598908 2.05236997 2.07297732]
# train_r2 : 0.2370
# [0.24020383 0.23806037 0.24140332 0.23198882 0.23311125]
# test_rmse : 2.0571
# [2.00070798 2.18351957 2.03748389 2.09920286 1.96447585]
# score_time : 0.0017
# [0.00210571 0.00181961 0.00171351 0.00165129 0.0012486 ]
# test_r2 : 0.2345
# [0.22167187 0.22746105 0.215277   0.25319531 0.25476984]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Lasso(alpha=1.49816047538945, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=42,
#    selection='cyclic', tol=0.0001, warm_start=False))])
# Socioeconomic indicator: Access to electricity
# fit_time : 0.3609
# [0.31382775 0.43479133 0.41256952 0.32188416 0.32166696]
# train_rmse : 0.1453
# [0.15194288 0.14685047 0.14291499 0.14061807 0.14403255]
# train_r2 : nan
# [1.03298421e-33            nan            nan            nan
#  7.90490625e-33]
# test_rmse : 0.1447
# [0.11575033 0.13925026 0.15474553 0.16312283 0.15052919]
# score_time : 0.0017
# [0.00218678 0.00146103 0.00180221 0.00170946 0.0013268 ]
# test_r2 : nan
# [2.02760870e-31 2.63041063e-31            nan            nan
#  1.05782576e-31]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Lasso(alpha=1.49816047538945, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=True, positive=False, precompute=False, random_state=42,
#    selection='cyclic', tol=0.0001, warm_start=False))])
# Socioeconomic indicator: Access to water (minutes)
# fit_time : 0.3367
# [0.31207561 0.30880904 0.41008878 0.33604407 0.31624389]
# train_rmse : 8.1018
# [6.40582874 8.12836855 8.48800305 8.77278344 8.71386315]
# train_r2 : 0.0141
# [0.01688645 0.01456267 0.01369873 0.01317846 0.01240355]
# test_rmse : 7.6162
# [12.97270824  8.23066431  6.6381061   4.91712191  5.32241207]
# score_time : 0.0017
# [0.00208354 0.00192022 0.0016346  0.00129104 0.0014236 ]
# test_r2 : 0.0173
# [0.01275113 0.01049172 0.01396336 0.02251026 0.02662994]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Lasso(alpha=3.8028572256396647, copy_X=True, fit_intercept=True,
#    max_iter=1000, normalize=False, positive=False, precompute=False,
#    random_state=42, selection='cyclic', tol=0.0001, warm_start=False))])

# %% [markdown]
# ### Ridge Regression

# %%
predictions = model_utils.evaluate_model(
    data=dhs,
    feature_cols=feature_cols, 
    indicator_cols=indicators, 
    scoring=scoring,
    model_type='ridge', 
    refit='r2', 
    search_type='grid', 
    n_splits=5
)
# Out:
# Socioeconomic indicator: Wealth Index
# fit_time : 0.5784
# [0.61164856 0.65713358 0.70978165 0.60197544 0.31146026]
# train_rmse : 58890.5972
# [58526.03351829 58875.58710743 59512.93369943 58437.3579941
#  59101.07378452]
# train_r2 : 0.3106
# [0.31250028 0.29842764 0.31757933 0.3131606  0.31144355]
# test_rmse : 59484.3481
# [60974.85714551 59642.14960594 56973.0716131  61242.56101706
#  58589.10109982]
# score_time : 0.0017
# [0.00194693 0.0015173  0.00161695 0.00183773 0.00142717]
# test_r2 : 0.3000
# [0.29232286 0.34671091 0.26584429 0.29248766 0.30240878]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Ridge(alpha=3.8028572256396647, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=42, solver='auto',
#    tol=0.001))])
# Socioeconomic indicator: Education completed (years)
# fit_time : 0.3226
# [0.36839867 0.30900884 0.31012273 0.31274056 0.31282854]
# train_rmse : 2.0240
# [2.04228231 1.99025689 2.02666174 2.01762914 2.04300165]
# train_r2 : 0.2562
# [0.25569887 0.25922846 0.26181079 0.25031803 0.25398055]
# test_rmse : 2.0385
# [1.9682329  2.17273357 2.02645663 2.062654   1.96258109]
# score_time : 0.0025
# [0.00204802 0.001544   0.00595617 0.00139141 0.00140357]
# test_r2 : 0.2461
# [0.246128   0.23383306 0.22188045 0.26953804 0.25915972]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Ridge(alpha=3.8028572256396647, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=42, solver='auto',
#    tol=0.001))])
# Socioeconomic indicator: Access to electricity
# fit_time : 0.3115
# [0.3091054  0.3182528  0.30917811 0.31046581 0.31057954]
# train_rmse : 0.1370
# [0.14295274 0.13841536 0.13468557 0.13260021 0.13656377]
# train_r2 : 0.1100
# [0.11483524 0.1115829  0.11185125 0.11078834 0.10102234]
# test_rmse : 0.1374
# [0.11226983 0.13248824 0.14752428 0.1546364  0.14013851]
# score_time : 0.0015
# [0.00132227 0.00217605 0.00125957 0.00156689 0.00128007]
# test_r2 : 0.1011
# [0.0827443  0.09329384 0.09022268 0.10186028 0.13756925]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Ridge(alpha=3.8028572256396647, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=42, solver='auto',
#    tol=0.001))])
# Socioeconomic indicator: Access to water (minutes)
# fit_time : 0.3162
# [0.30863261 0.31107688 0.32851815 0.32301092 0.30961752]
# train_rmse : 8.0587
# [6.38192174 8.09348962 8.42392294 8.71717228 8.6769911 ]
# train_r2 : 0.0240
# [0.02336213 0.02288637 0.02806719 0.02517608 0.02026343]
# test_rmse : 7.6264
# [12.91201845  8.19138148  6.75524169  5.01222448  5.26093279]
# score_time : 0.0018
# [0.00220847 0.00145006 0.00230503 0.00188017 0.00120258]
# test_r2 : 0.0233
# [0.02649733 0.02005884 0.00532275 0.01495884 0.04970098]
# Best estimator: Pipeline(memory=None,
#      steps=[('regressor', Ridge(alpha=1.49816047538945, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=42, solver='auto', tol=0.001))])
