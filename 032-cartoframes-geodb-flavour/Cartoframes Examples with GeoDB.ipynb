# %%
from cartoframes.auth import set_default_credentials
# Out:
# NumExpr defaulting to 4 threads.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
GEODB_USERNAME=os.getenv('GEODB_USERNAME')
GEODB_MASTER_API_KEY=os.getenv('GEODB_MASTER_API_KEY')
GEODB_SERVER_URI=os.getenv('GEODB_SERVER_URI')

# %%
# get context with authentication

# %%
from cartoframes.auth import Credentials

# %%
auth_credentials = Credentials(
    base_url=f"{GEODB_SERVER_URI}/user/{GEODB_USERNAME}", 
    api_key=GEODB_MASTER_API_KEY
)

# %%
set_default_credentials(credentials=auth_credentials)

# %%
import pyproj
import fiona
from geopandas import read_file

gdf = read_file('https://bit.ly/3Dc84I7')

# %%
gdf = gdf.drop(['cartodb_id'], axis=1)

# %%
gdf.head()
# Out:
#    field_1                          name  \
# 0        0   Franklin Ave & Eastern Pkwy
# 1        1        607 Brighton Beach Ave
# 2        2            65th St & 18th Ave
# 3        3      Bay Ridge Pkwy & 3rd Ave
# 4        4  Caesar's Bay Shopping Center
#
#                                         address      revenue  \
# 0           341 Eastern Pkwy,Brooklyn, NY 11238  1321040.772
# 1  607 Brighton Beach Avenue,Brooklyn, NY 11235  1268080.418
# 2           6423 18th Avenue,Brooklyn, NY 11204  1248133.699
# 3            7419 3rd Avenue,Brooklyn, NY 11209  1185702.676
# 4           8973 Bay Parkway,Brooklyn, NY 11214  1148427.411
#
#                      geometry
# 0  POINT (-73.95901 40.67109)
# 1  POINT (-73.96122 40.57796)
# 2  POINT (-73.98976 40.61912)
# 3  POINT (-74.02744 40.63152)
# 4  POINT (-74.00098 40.59321)

# %%
from cartoframes import to_carto

to_carto(gdf, 'starbucks_brooklyn')
# Out:
# Success! Data uploaded to table "starbucks_brooklyn" correctly
# 'starbucks_brooklyn'

# %%
from cartoframes import delete_table

delete_table('starbucks_brooklyn')
# Out:
# Success! Table "starbucks_brooklyn" removed correctly

# %%
from cartoframes.viz import Layer

Layer(gdf_remote)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
from pandas import read_csv
from geopandas import read_file

polygons_df = read_csv('http://libs.cartocdn.com/cartoframes/samples/starbucks_brooklyn_iso_enriched.csv')
polygons_gdf = read_file('http://libs.cartocdn.com/cartoframes/samples/starbucks_brooklyn_iso_enriched.geojson')

# %%
from cartoframes.viz import Map

Map([
    Layer(polygons_df, geom_col='the_geom'),
    Layer(gdf_remote)
])
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
from cartoframes.viz import size_continuous_style

Layer(
    gdf_remote,
    size_continuous_style('revenue')
)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
from cartoframes.viz import size_continuous_style, size_continuous_legend  # or just default_legend

Layer(
    gdf_remote,
    size_continuous_style('revenue', size_range=[10,50], stroke_color='turquoise', stroke_width=2, opacity=0),
    legends=size_continuous_legend(
        title='Annual Revenue',
        description='Revenue in dollars ($)',
        footer='Source: <a href="https://www.starbucks.com/">Starbucks</a>'
    )
)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
from cartoframes.viz import formula_widget, category_widget, histogram_widget

map_viz_nyc = Map(Layer(
    polygons_gdf,
    widgets=[
        formula_widget('popcy', 'sum', 'Population'),
        formula_widget('inccymedhh', 'sum', 'Median Income Average', is_global=True),
        histogram_widget('educybach', 'Education'),
        category_widget('id_store', 'Store ID')
    ]
))

# %%
map_viz_nyc.publish(name='nyc_pop', password='1234', if_exists='replace')
# Out:
# {'id': 'ec539b1f-aef2-4c46-9445-c2deae30cc99',
#  'url': 'https://ag.perigonai.com/user/shoaib/kuviz/ec539b1f-aef2-4c46-9445-c2deae30cc99',
#  'name': 'nyc_pop',
#  'privacy': 'password'}

# %%
from cartoframes.viz import popup_element

Layer(
    polygons_gdf,
    popup_hover=[
        popup_element('popcy', 'Population')
    ],
    popup_click=[
        popup_element('popcy', 'Population'),
        popup_element('id_store', 'Store ID'),
        popup_element('inccymedhh', 'Median Income'),
        popup_element('lbfcyempl', 'Employed Population'),
    ]
)
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
from cartoframes.viz import Layout
from cartoframes.viz import Layer, color_bins_style

map_layout = Layout([
    Map(Layer(polygons_gdf, style=color_bins_style('inccymedhh', bins=7, palette='mint', stroke_width=0))),
    Map(Layer(polygons_gdf, style=color_bins_style('popcy', palette='pinkyl', stroke_width=0)))
], 2, 1, map_height=400, is_static=True)
map_layout
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 400px;;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>CARTOframes</title>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %%
map_layout.publish(name='map_side_by_side', password='1234', if_exists='replace')
# Out:
# {'id': '15c44a27-4a81-42cf-ad39-95ab4f486ad8',
#  'url': 'https://ag.perigonai.com/user/shoaib/kuviz/15c44a27-4a81-42cf-ad39-95ab4f486ad8',
#  'name': 'map_side_by_side',
#  'privacy': 'password'}

# %%
map_viz = Map(Layer(polygons_gdf, style=color_bins_style('popcy', palette='pinkyl', stroke_width=0)))

# %%
map_viz.publish(
    name='nyc',
    password='1234',
    if_exists='replace')
# Out:
# {'id': 'b835c33b-9381-495b-82b2-9008ef298085',
#  'url': 'https://ag.perigonai.com/user/shoaib/kuviz/b835c33b-9381-495b-82b2-9008ef298085',
#  'name': 'nyc',
#  'privacy': 'password'}
